# %%
import pandas as pd
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

train_dummy=train.copy()
test_dummy=test.copy()

# %%
y=train.Y
train=train.drop('Y',1)

# %%
train.head()
# Out:
#    Time          X1          X2          X3          X4          X5  \
# 0     1  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     2   91.567862   96.621901   98.084599   96.543909   91.678881
# 2     3   92.908600   97.640753  103.112398   98.130312   78.041958
# 3     4   84.869178   94.369892  109.018217  102.209632   73.357203
# 4     5   88.888889   95.603221  108.459686  103.116147   77.832727
#
#            X6        X7          X8          X9     ...             X91  \
# 0  100.000000  100.0000  100.000000  100.000000     ...      100.000000
# 1   96.337918   96.1250   94.015957   94.409201     ...       97.292714
# 2   97.693843   95.6250   95.744681   94.089712     ...       95.093172
# 3  100.676878   96.9166   93.085106   98.243067     ...       97.461792
# 4  104.677398  100.8750   93.617021  100.000000     ...      102.537953
#
#           X92         X93         X94         X95         X96         X97  \
# ...

# %%
test.head()
# Out:
#    Time           X1         X2          X3          X4          X5  \
# 0  3001  1226.497073  44.645538  209.519285  221.218130  234.394406
# 1  3002  1247.828806  44.662696  208.395584  219.008499  238.534266
# 2  3003  1256.976337  45.177441  208.318968  216.770538  239.653147
# 3  3004  1276.417029  45.932400  210.336523  220.311615  242.506294
# 4  3005  1285.384461  46.189773  210.489755  217.847026  244.229371
#
#            X6     X7         X8          X9    ...            X91         X92  \
# 0  146.005988  38.40  67.404255  146.504792    ...      66.558375  144.331852
# 1  146.700221  38.08  67.297872  145.277955    ...      65.638920  142.862222
# 2  146.548358  38.10  66.446809  143.744409    ...      66.277430  141.700741
# 3  147.351065  38.60  66.446809  146.504792    ...      67.401210  143.620741
# 4  146.591747  37.98  66.255319  144.664537    ...      65.894324  141.819259
#
#           X93         X94         X95         X96        X97         X98  \
# ...

# %%
import numpy as np

# %%
train=train.drop('Time',1)
train_dummy=train_dummy.drop('Time',1)
test_dummy=test_dummy.drop('Time',1)

# %%
test=test.drop('Time',1)

# %%
train.head()
# Out:
#            X1          X2          X3          X4          X5          X6  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   91.567862   96.621901   98.084599   96.543909   91.678881   96.337918
# 2   92.908600   97.640753  103.112398   98.130312   78.041958   97.693843
# 3   84.869178   94.369892  109.018217  102.209632   73.357203  100.676878
# 4   88.888889   95.603221  108.459686  103.116147   77.832727  104.677398
#
#          X7          X8          X9         X10     ...             X91  \
# 0  100.0000  100.000000  100.000000  100.000000     ...      100.000000
# 1   96.1250   94.015957   94.409201   97.084183     ...       97.292714
# 2   95.6250   95.744681   94.089712   96.655229     ...       95.093172
# 3   96.9166   93.085106   98.243067   98.113343     ...       97.461792
# 4  100.8750   93.617021  100.000000   99.828542     ...      102.537953
#
#           X92         X93         X94         X95         X96         X97  \
# ...

# %%
test.head()
# Out:
#             X1         X2          X3          X4          X5          X6  \
# 0  1226.497073  44.645538  209.519285  221.218130  234.394406  146.005988
# 1  1247.828806  44.662696  208.395584  219.008499  238.534266  146.700221
# 2  1256.976337  45.177441  208.318968  216.770538  239.653147  146.548358
# 3  1276.417029  45.932400  210.336523  220.311615  242.506294  147.351065
# 4  1285.384461  46.189773  210.489755  217.847026  244.229371  146.591747
#
#       X7         X8          X9        X10    ...            X91         X92  \
# 0  38.40  67.404255  146.504792  85.584964    ...      66.558375  144.331852
# 1  38.08  67.297872  145.277955  84.452888    ...      65.638920  142.862222
# 2  38.10  66.446809  143.744409  83.485478    ...      66.277430  141.700741
# 3  38.60  66.446809  146.504792  85.049801    ...      67.401210  143.620741
# 4  37.98  66.255319  144.664537  83.855975    ...      65.894324  141.819259
#
# ...

# %%
test.head()
# Out:
#             X1         X2          X3          X4          X5          X6  \
# 0  1226.497073  44.645538  209.519285  221.218130  234.394406  146.005988
# 1  1247.828806  44.662696  208.395584  219.008499  238.534266  146.700221
# 2  1256.976337  45.177441  208.318968  216.770538  239.653147  146.548358
# 3  1276.417029  45.932400  210.336523  220.311615  242.506294  147.351065
# 4  1285.384461  46.189773  210.489755  217.847026  244.229371  146.591747
#
#       X7         X8          X9        X10    ...            X91         X92  \
# 0  38.40  67.404255  146.504792  85.584964    ...      66.558375  144.331852
# 1  38.08  67.297872  145.277955  84.452888    ...      65.638920  142.862222
# 2  38.10  66.446809  143.744409  83.485478    ...      66.277430  141.700741
# 3  38.60  66.446809  146.504792  85.049801    ...      67.401210  143.620741
# 4  37.98  66.255319  144.664537  83.855975    ...      65.894324  141.819259
#
# ...

# %%
def outlier_detection(x):
    q75, q25 = np.percentile(x, [75 ,25])
    iqr = q75 - q25
    l=q25-iqr
    u=q75+iqr
    return l,u

# %%
for i in range(0,len(train.iloc[:,0])):
    l,u=outlier_detection(train.iloc[i,:])
    for j in range(0,100):
        if (train.iloc[i,j:j+1]).values[0]>u:
            train.iloc[i,j:j+1].values[0]=u
        elif train.iloc[i,j:j+1].values[0]<l:
            train.iloc[i,j:j+1].values[0]=l
            
for i in range(0,len(test.iloc[:,0])):
    l,u=outlier_detection(test.iloc[i,:])
    for j in range(0,100):
        if (test.iloc[i,j:j+1]).values[0]>u:
            test.iloc[i,j:j+1].values[0]=u
        elif test.iloc[i,j:j+1].values[0]<l:
            test.iloc[i,j:j+1].values[0]=l

# %%
train.head()
# Out:
#            X1          X2          X3          X4          X5          X6  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   91.567862   96.621901   98.084599   96.543909   91.678881   96.337918
# 2   92.908600   97.640753  103.112398   98.130312   88.753905   97.693843
# 3   90.684223   94.369892  108.874356  102.209632   90.684223  100.676878
# 4   90.101505   95.603221  108.459686  103.116147   90.101505  104.677398
#
#          X7          X8          X9         X10     ...             X91  \
# 0  100.0000  100.000000  100.000000  100.000000     ...      100.000000
# 1   96.1250   94.015957   94.409201   97.084183     ...       97.292714
# 2   95.6250   95.744681   94.089712   96.655229     ...       95.093172
# 3   96.9166   93.085106   98.243067   98.113343     ...       97.461792
# 4  100.8750   93.617021  100.000000   99.828542     ...      102.537953
#
#           X92         X93         X94         X95         X96         X97  \
# ...

# %%
(train.iloc[1,:])
# Out:
# X1       91.567862
# X2       96.621901
# X3       98.084599
# X4       96.543909
# X5       91.678881
# X6       96.337918
# X7       96.125000
# X8       94.015957
# X9       94.409201
# X10      97.084183
# X11      96.351731
# X12      95.620450
# X13      98.075710
# X14      96.470588
# X15      99.111111
# X16      99.327474
# X17      94.726023
# X18      92.513163
# X19      95.330575
# X20      96.487887
# X21     102.600653
# X22      97.458983
# X23      96.971336
# X24      94.389733
# X25      94.064528
# X26      98.720048
# X27     100.800030
# X28      95.626477
# X29      92.337531
# X30      92.352792
#            ...
# X71      96.370364
# X72      92.989076
# X73      96.777906
# X74      94.769697
# X75     101.099203
# X76      98.069051
# X77      98.932214
# X78      97.070000
# X79      91.611045
# X80     102.459279
# X81      99.120312
# X82      98.714653
# X83      95.663493
# X84      94.133458
# X85     100.000000
# X86     100.000000
# ...

# %%
from sklearn import preprocessing


for i in range(0,len(train.iloc[:,0])):
    train.iloc[i,:]=(preprocessing.normalize(train.iloc[i,:], norm='l2'))
    
for i in range(0,len(test.iloc[:,0])):
    test.iloc[i,:]=(preprocessing.normalize(test.iloc[i,:], norm='l2'))
# Out:
# /home/subir_sbr/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /home/subir_sbr/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...

# %%
train.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 1  0.094347  0.099554  0.101061  0.099474  0.094461  0.099261  0.099042
# 2  0.095087  0.099930  0.105530  0.100431  0.090835  0.099984  0.097867
# 3  0.090840  0.094532  0.109062  0.102385  0.090840  0.100850  0.097083
# 4  0.087316  0.092648  0.105107  0.099928  0.087316  0.101441  0.097756
#
#          X8        X9       X10    ...          X91       X92       X93  \
# 0  0.100000  0.100000  0.100000    ...     0.100000  0.100000  0.100000
# 1  0.096869  0.097274  0.100030    ...     0.100245  0.099829  0.098397
# 2  0.097989  0.096295  0.098921    ...     0.097322  0.099615  0.098639
# 3  0.093245  0.098412  0.098282    ...     0.097629  0.102101  0.096154
# 4  0.090723  0.096908  0.096742    ...     0.099368  0.098918  0.098995
#
#         X94       X95       X96       X97       X98       X99      X100
# ...

# %%
train.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 1  0.094347  0.099554  0.101061  0.099474  0.094461  0.099261  0.099042
# 2  0.095087  0.099930  0.105530  0.100431  0.090835  0.099984  0.097867
# 3  0.090840  0.094532  0.109062  0.102385  0.090840  0.100850  0.097083
# 4  0.087316  0.092648  0.105107  0.099928  0.087316  0.101441  0.097756
#
#          X8        X9       X10    ...          X91       X92       X93  \
# 0  0.100000  0.100000  0.100000    ...     0.100000  0.100000  0.100000
# 1  0.096869  0.097274  0.100030    ...     0.100245  0.099829  0.098397
# 2  0.097989  0.096295  0.098921    ...     0.097322  0.099615  0.098639
# 3  0.093245  0.098412  0.098282    ...     0.097629  0.102101  0.096154
# 4  0.090723  0.096908  0.096742    ...     0.099368  0.098918  0.098995
#
#         X94       X95       X96       X97       X98       X99      X100
# ...

# %%
train.columns[100:,]
# Out:
# Index([], dtype='object')

# %%
from xgboost import XGBClassifier
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import StratifiedKFold
from sklearn import linear_model

# %%
model = XGBClassifier()
learning_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]
n_estimators=[150,200,250,300,350,400]

param_grid = dict(learning_rate=learning_rate,n_estimators=n_estimators)
kfold = StratifiedKFold(y, n_folds=5, shuffle=True, random_state=7)
grid_search = GridSearchCV(model, param_grid, scoring="accuracy", n_jobs=-1, cv=kfold)
result = grid_search.fit(train,y)
# summarize results
print("Best: %f using %s" % (result.best_score_, result.best_params_))
means, stdevs = [], []
for params, mean_score, scores in result.grid_scores_:
    stdev = scores.std()
    means.append(mean_score)
    stdevs.append(stdev)
    print("%f (%f) with: %r" % (mean_score, stdev, params))
# Out:
# Best: 0.537000 using {'learning_rate': 0.01, 'n_estimators': 150}
# 0.494667 (0.011279) with: {'learning_rate': 0.0001, 'n_estimators': 150}
# 0.494667 (0.011279) with: {'learning_rate': 0.0001, 'n_estimators': 200}
# 0.494000 (0.012280) with: {'learning_rate': 0.0001, 'n_estimators': 250}
# 0.494667 (0.011785) with: {'learning_rate': 0.0001, 'n_estimators': 300}
# 0.497000 (0.013473) with: {'learning_rate': 0.0001, 'n_estimators': 350}
# 0.497000 (0.013473) with: {'learning_rate': 0.0001, 'n_estimators': 400}
# 0.508333 (0.014273) with: {'learning_rate': 0.001, 'n_estimators': 150}
# 0.507000 (0.014443) with: {'learning_rate': 0.001, 'n_estimators': 200}
# 0.512667 (0.015127) with: {'learning_rate': 0.001, 'n_estimators': 250}
# 0.513667 (0.016277) with: {'learning_rate': 0.001, 'n_estimators': 300}
# 0.520333 (0.019967) with: {'learning_rate': 0.001, 'n_estimators': 350}
# 0.527000 (0.021772) with: {'learning_rate': 0.001, 'n_estimators': 400}
# ...

# %%
#0.531333 using {'n_estimators': 300, 'learning_rate': 0.01}

# %%
from xgboost import plot_importance
from matplotlib import pyplot
model.fit(train,y)  

plot_importance(model)
pyplot.xticks(rotation=90)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-3bd10bd16e03> in <module>()
#       6 plot_importance(model)
#       7 pyplot.xticks(rotation=120)
# ----> 8 pyplot.show()
#
# /home/subir_sbr/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     250     """
#     251     global _show
# --> 252     return _show(*args, **kw)
#     253
#     254
#
# /home/subir_sbr/anaconda3/lib/python3.5/site-packages/matplotlib/backend_bases.py in __call__(self, block)
#     190
#     191         if not is_interactive() or get_backend() == 'WebAgg':
# --> 192             self.mainloop()
#     193
#     194     def mainloop(self):
#
# /home/subir_sbr/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_tkagg.py in mainloop(self)
#      72 class Show(ShowBase):
#      73     def mainloop(self):
# ---> 74         Tk.mainloop()
#      75
# ...

# %%
# Out:
# dict_values([2, 7, 1, 2, 27, 6, 3, 21, 6, 1, 18, 7, 1, 9, 4, 8, 3, 7, 5, 2, 11, 4, 5, 5, 9, 6, 1, 2, 4, 8, 6, 6, 9, 6, 4, 9, 3, 1, 5, 3, 13, 3, 4, 5, 6, 8, 3, 1, 8, 3, 1, 9, 4, 4, 4, 14, 6, 10, 9, 7, 11, 2, 2, 7, 11, 1, 2, 4, 2, 7, 14, 9, 3, 10, 1, 3, 5, 5, 2, 3, 9, 1, 10, 2, 1, 1, 12, 4, 2, 6, 2, 6, 5, 4, 4, 3, 6, 10, 11])

# %%
model=XGBClassifier(n_estimators=150, learning_rate=0.01)
from sklearn import cross_validation
cv = cross_validation.KFold(len(train), n_folds=5,random_state=7)
for traincv,testcv in cv:
    model.fit(train.iloc[traincv],y.iloc[traincv])

# %%
y_XGB=model.predict(test)
np.unique(y_XGB)
# Out:
# array([-1,  1])

# %%
from sklearn.ensemble import AdaBoostClassifier
model = AdaBoostClassifier()
learning_rate = [0.5,0.2,0.1,0.01,0.001,0.0001]
n_estimators=[100,200,300,400,500,600]

param_grid = dict(learning_rate=learning_rate,n_estimators=n_estimators)
kfold = StratifiedKFold(y, n_folds=5, shuffle=True, random_state=7)
grid_search = GridSearchCV(model, param_grid, scoring="accuracy", n_jobs=-1, cv=kfold)
result = grid_search.fit(train,y)
# summarize results
print("Best: %f using %s" % (result.best_score_, result.best_params_))
means, stdevs = [], []
for params, mean_score, scores in result.grid_scores_:
    stdev = scores.std()
    means.append(mean_score)
    stdevs.append(stdev)
    print("%f (%f) with: %r" % (mean_score, stdev, params))
# Out:
# Best: 0.535333 using {'learning_rate': 0.01, 'n_estimators': 300}
# 0.520333 (0.021918) with: {'learning_rate': 0.5, 'n_estimators': 100}
# 0.523333 (0.016836) with: {'learning_rate': 0.5, 'n_estimators': 200}
# 0.512667 (0.016426) with: {'learning_rate': 0.5, 'n_estimators': 300}
# 0.511000 (0.018254) with: {'learning_rate': 0.5, 'n_estimators': 400}
# 0.512667 (0.016339) with: {'learning_rate': 0.5, 'n_estimators': 500}
# 0.510000 (0.013037) with: {'learning_rate': 0.5, 'n_estimators': 600}
# 0.530333 (0.017934) with: {'learning_rate': 0.2, 'n_estimators': 100}
# 0.530000 (0.017275) with: {'learning_rate': 0.2, 'n_estimators': 200}
# 0.526333 (0.020767) with: {'learning_rate': 0.2, 'n_estimators': 300}
# 0.524000 (0.018783) with: {'learning_rate': 0.2, 'n_estimators': 400}
# 0.523333 (0.021123) with: {'learning_rate': 0.2, 'n_estimators': 500}
# 0.520667 (0.016669) with: {'learning_rate': 0.2, 'n_estimators': 600}
# ...

# %%
model2 = AdaBoostClassifier(learning_rate=0.01, n_estimators=300)
cv = cross_validation.KFold(len(train), n_folds=5,random_state=7)
for traincv,testcv in cv:
    model2.fit(train.iloc[traincv],y.iloc[traincv])

# %%
y_ADB=model2.predict(test)

# %%
df_XGB=pd.DataFrame(y_XGB,columns=['y'])
df_ADB=pd.DataFrame(y_ADB,columns=['y'])

# %%
df_XGB.y.value_counts()
# Out:
# -1    1360
#  1       1
# Name: y, dtype: int64

# %%
df_ADB.y.value_counts()
# Out:
# -1    1361
# Name: y, dtype: int64

# %%
from sklearn.cross_validation import train_test_split
dummy=pd.concat([train,y],1)
df_train, df_test = train_test_split(dummy, train_size = 0.5)

# %%
df_train.head()
# Out:
#             X1        X2        X3        X4        X5        X6        X7  \
# 477   0.027157  0.043181  0.087205  0.115441  0.013744  0.108744  0.063030
# 474   0.027969  0.044741  0.087920  0.114912  0.016736  0.106720  0.065197
# 1405  0.084584  0.026416  0.083243  0.093804  0.023767  0.086871  0.044269
# 1924  0.163094  0.021945  0.088210  0.084720  0.029381  0.057078  0.030665
# 2452  0.198164  0.020458  0.103314  0.098426  0.051095  0.069672  0.015388
#
#             X8        X9       X10 ...       X92       X93       X94  \
# 477   0.070184  0.087386  0.062997 ...  0.112638  0.077511  0.155355
# 474   0.069930  0.088076  0.064803 ...  0.114773  0.080123  0.152939
# 1405  0.030020  0.093428  0.044004 ...  0.078010  0.079540  0.031476
# 1924  0.036277  0.077233  0.044863 ...  0.073662  0.066804  0.083791
# 2452  0.030333  0.072908  0.042255 ...  0.057717  0.060106  0.070135
#
#            X95       X96       X97       X98       X99      X100  Y
# ...

# %%
y_train=df_train.Y
df_train=df_train.drop('Y',1)
y_test=df_test.Y
df_test=df_test.drop('Y',1)

# %%
model1=XGBClassifier(n_estimators=150, learning_rate=0.001)
model2 = AdaBoostClassifier(learning_rate=0.01, n_estimators=500)

# %%
model1.fit(df_train,y_train)
y_pred_model1=model1.predict(df_test)

model2.fit(df_train,y_train)
y_pred_model2=model2.predict(df_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred_model1)
(497+265)/(466+265+272+497)
# Out:
# 0.508

# %%
confusion_matrix(y_test, y_pred_model2)
(386+397)/(386+334+383+397)
# Out:
# 0.522

# %%
frame=pd.DataFrame(data=df_XGB.y,columns=['y'])
for i in range(0,len(df_ADB)):
    if (df_ADB.y[i]==1) & (df_XGB.y[i]==1):
        frame.y[i]=1
    elif (df_ADB.y[i]==-1) & (df_XGB.y[i]==-1):
        frame.y[i]=-1
    elif (df_ADB.y[i]==-1) & (df_XGB.y[i]==1):
        frame.y[i]=1
    elif (df_ADB.y[i]==1) & (df_XGB.y[i]==-1):
        frame.y[i]=1

# %%
frame.y.value_counts()
# Out:
# -1    1360
#  1       1
# Name: y, dtype: int64

# %%
frame2=pd.DataFrame(data=y_pred_model1,columns=['y'])
for i in range(0,len(df_ADB)):
    if (y_pred_model2[i]==1) & (y_pred_model1[i]==1):
        frame2.y[i]=1
    elif (y_pred_model2[i]==-1) & (y_pred_model1[i]==-1):
        frame2.y[i]=-1
    elif (y_pred_model2[i]==-1) & (y_pred_model1[i]==1):
        frame2.y[i]=-1
    elif (y_pred_model2[i]==1) & (y_pred_model1[i]==-1):
        frame2.y[i]=1

# %%
frame2.y.value_counts()
# Out:
# -1    1108
#  1     392
# Name: y, dtype: int64

# %%
mat=confusion_matrix(y_test, frame2.y)

# %%
(mat[0][0]+mat[1][1])/(mat[0][0]+mat[0][1]+mat[1][0]+mat[1][1])
# Out:
# 0.5

# %%
file = open("final_pred.txt", "a")
file.write("Time,Y\n")
for i in range(0,len(df_ADB)):
    file.write(str(3000+i))
    file.write(",")
    file.write(str(frame2.y[i]))
    file.write("\n")
    
file.close()

# %%
len(df_ADB)
# Out:
# 1361

# %%
nn=pd.read_csv("nn.txt")

# %%
nn.Y.value_counts()
# Out:
# -1.0    1022
#  1.0     339
# Name: Y, dtype: int64
